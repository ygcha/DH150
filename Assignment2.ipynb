# %% [markdown]
# # Assignment 2 - Christina Cha

# %% [markdown]
# ### Import scikit-learn's example diabetes dataset with the following code:

# %%
import sklearn.datasets
diabetes = sklearn.datasets.load_diabetes()

# %% [markdown]
# ### Print a description of the dataset with:

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %% [markdown]
# ### Get the features and target arrays with:

# %%
x = diabetes.data
y = diabetes.target

# %% [markdown]
# ### Look at x : output one of the records to see that it has the expected number of features (attributes)
# Hint: there should be 10 features in x, and 442 records (patients)

# %%
features = diabetes.feature_names
print(features)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
import pandas as pd

df=pd.DataFrame(x, columns = features)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %% [markdown]
# ### Make a scatter plot using just one of the features in x vs the target variable y:

# %%
#BMI
bmi = x[:,2]

diabetesDict = {
    'BMI' : bmi,
    'Target' : y
}

df1= pd.DataFrame(diabetesDict)
df1.plot.scatter(x = 'BMI', y = 'Target')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Target'>

# %% [markdown]
# ### Make plots with several features until you find one that you think may have a good linear relationship with y.

# %%
#Age
age = x[:,0]

diabetesDict = {
    'Age' : age,
    'Target' : y
}

df2= pd.DataFrame(diabetesDict)
df2.plot.scatter(x = 'Age', y = 'Target')

#BP
bp = x[:,3]

diabetesDict = {
    'BP' : bp,
    'Target' : y
}

df3= pd.DataFrame(diabetesDict)
df3.plot.scatter(x = 'BP', y = 'Target')

#S1
s1 = x[:,4]

diabetesDict = {
    'S1' : s1,
    'Target' : y
}

df4= pd.DataFrame(diabetesDict)
df4.plot.scatter(x = 'S1', y = 'Target')

#S2
s2 = x[:,5]

diabetesDict = {
    'S2' : s2,
    'Target' : y
}

df5= pd.DataFrame(diabetesDict)
df5.plot.scatter(x = 'S2', y = 'Target')

#S3
s3 = x[:,6]

diabetesDict = {
    'S3' : s3,
    'Target' : y
}

df6= pd.DataFrame(diabetesDict)
df6.plot.scatter(x = 'S3', y = 'Target')
# Out:
# <AxesSubplot:xlabel='S3', ylabel='Target'>

# %%
# Age has a good linear relationship with y.

# %% [markdown]
# ### Step 4: Do regression with linear regression
# Using the feature you've identified in x and the target variable y, perform linear regression with sklearn's LinearRegression.
# Be sure to use a train/test split

# %%
import numpy as np
import seaborn as sns
import sklearn.linear_model
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# Select a linear regression model
model = sklearn.linear_model.LinearRegression()

# %%
x = df2[['Age']]
y = df2['Target']

df2.plot.scatter(x='Age', y='Target', title='Scatterplot of Age and Target');

# %%
print(df2.corr())
print(df2.describe())
# Out:
#              Age    Target
# Age     1.000000  0.187889
# Target  0.187889  1.000000
#                 Age      Target
# count  4.420000e+02  442.000000
# mean  -3.634285e-16  152.133484
# std    4.761905e-02   77.093005
# min   -1.072256e-01   25.000000
# 25%   -3.729927e-02   87.000000
# 50%    5.383060e-03  140.500000
# 75%    3.807591e-02  211.500000
# max    1.107267e-01  346.000000

# %%
X = df2['Age'].values.reshape(-1, 1)
y = df2['Target'].values.reshape(-1, 1)

# %%
# Train, Test, Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
X_train.shape
# Out:
# (265, 1)

# %%
X_test.shape
# Out:
# (177, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# Coefficient 
print(model.coef_, model.intercept_)
# Out:
# [[311.82444518]] [150.82678544]

# %%
# Make a prediction
X_sample = X_test
y_pred = model.predict(X_test)
for i in range(len(y_test)):
    print(y_test[i], y_pred[i])
# Out:
# [219.] [164.96521242]
# [70.] [179.69049815]
# [202.] [170.62878385]
# [230.] [180.82321244]
# [111.] [154.77078383]
# [84.] [153.63806954]
# [242.] [147.97449811]
# [272.] [143.44364096]
# [94.] [121.92206951]
# [96.] [132.11649809]
# [94.] [137.78006953]
# [252.] [152.50535526]
# [99.] [123.05478379]
# [297.] [157.03621241]
# [135.] [146.84178382]
# [67.] [140.0454981]
# [295.] [163.83249813]
# [264.] [170.62878385]
# [170.] [141.17821239]
# [275.] [166.0979267]
# [310.] [128.71835523]
# [64.] [166.0979267]
# [128.] [137.78006953]
# [232.] [169.49606956]
# [129.] [132.11649809]
# [118.] [163.83249813]
# [263.] [160.43435527]
# [77.] [162.69978384]
# [48.] [133.24921238]
# [107.] [155.90349812]
# [140.] [159.30164098]
# [113.] [118.52392664]
# [90.] [150.23992668]
# [164.] [159.30164098]
# [180.] [180.82321244]
# [233.] [126.45292665]
# [42.] [147.97449811]
# [84.] [150.23992668]
# [172.] [171.76149814]
# [63.] [157.03621241]
# [48.] [150.23992668]
# [108.] [171.76149814]
# ...

# %%
# Visualize what the predictions are for this model

plt.plot(X_test,y_test,'ko')

X_new = np.linspace(-0.15,0.15)
X_new = X_new.reshape(-1,1)
y_pred = model.predict(X_new)
plt.plot(X_new, y_pred)

plt.show()

# %%
# Visualize what the predictions are for this model

plt.plot(X_train,y_train,'bo')

X_new = np.linspace(-0.15,0.15)
X_new = X_new.reshape(-1,1)
y_pred = model.intercept_ + model.coef_ * X_new
plt.plot(X_new, y_pred)

plt.show()

# %%
# Visualize what the predictions are for this model

plt.plot(X_train,y_train,'bo')
plt.plot(X_test,y_test,'ko')

X_new = np.linspace(-0.15,0.15)
X_new = X_new.reshape(-1,1)
y_pred = model.intercept_ + model.coef_ * X_new
plt.plot(X_new, y_pred)

plt.show()

# %%
y_pred = model.predict(X_test)
df_preds = pd.DataFrame({'Actual': y_test.squeeze(), 'Predicted': y_pred.squeeze()})
print(df_preds)
# Out:
#      Actual   Predicted
# 0     219.0  164.965212
# 1      70.0  179.690498
# 2     202.0  170.628784
# 3     230.0  180.823212
# 4     111.0  154.770784
# ..      ...         ...
# 172   199.0  176.292355
# 173   265.0  154.770784
# 174   281.0  158.168927
# 175   248.0  172.894212
# 176   257.0  142.310927
#
# [177 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score

print('MSE = ', mean_squared_error(y_test, model.predict(X_test)))
print('R^2 = ', r2_score(y_test, model.predict(X_test)))
# Out:
# MSE =  5659.036676322969
# R^2 =  0.032676248473723635

# %% [markdown]
# #### Do this process again for a different feature variable, and comment on how the new values for mean squared error and R-squared scores compare

# %%
# Select a linear regression model
model = sklearn.linear_model.LinearRegression()

# %%
x1 = df1[['BMI']]
y1 = df1['Target']

df1.plot.scatter(x='BMI', y='Target', title='Scatterplot of BMI and Target');

# %%
print(df1.corr())
print(df1.describe())
# Out:
#             BMI   Target
# BMI     1.00000  0.58645
# Target  0.58645  1.00000
#                 BMI      Target
# count  4.420000e+02  442.000000
# mean  -8.045349e-16  152.133484
# std    4.761905e-02   77.093005
# min   -9.027530e-02   25.000000
# 25%   -3.422907e-02   87.000000
# 50%   -7.283766e-03  140.500000
# 75%    3.124802e-02  211.500000
# max    1.705552e-01  346.000000

# %%
X1 = df1['BMI'].values.reshape(-1, 1)
y1 = df1['Target'].values.reshape(-1, 1)

# %%
# Train, Test, Split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.4, random_state = 42)

# %%
X1_train.shape
# Out:
# (265, 1)

# %%
X1_test.shape
# Out:
# (177, 1)

# %%
model = LinearRegression()
model.fit(X1_train, y1_train)

# Coefficient 
print(model.coef_, model.intercept_)
# Out:
# [[980.74210468]] [148.53674348]

# %%
# Make a prediction
X1_sample = X1_test
y1_pred = model.predict(X1_test)
for i in range(len(y1_test)):
    print(y1_test[i], y1_pred[i])
# Out:
# [219.] [142.45030296]
# [70.] [184.73253023]
# [202.] [144.56441432]
# [230.] [199.53130978]
# [111.] [128.7085791]
# [84.] [124.48035637]
# [242.] [315.80743477]
# [272.] [193.18897568]
# [94.] [59.99995978]
# [96.] [163.59141659]
# [94.] [116.02391091]
# [252.] [91.71163023]
# [99.] [88.54046319]
# [297.] [162.53436091]
# [135.] [93.8257416]
# [67.] [154.07791546]
# [295.] [218.55831205]
# [264.] [235.47120296]
# [170.] [176.27608478]
# [275.] [205.87364387]
# [310.] [186.84664159]
# [64.] [106.51040978]
# [128.] [100.16807569]
# [232.] [170.99080637]
# [129.] [192.13192]
# [118.] [162.53436091]
# [263.] [206.93069955]
# [77.] [130.82269046]
# [48.] [75.85579501]
# [107.] [127.65152341]
# [140.] [239.69942568]
# [113.] [111.79568819]
# [90.] [162.53436091]
# [164.] [142.45030296]
# [180.] [187.90369728]
# [233.] [224.90064614]
# [42.] [118.13802228]
# [84.] [116.02391091]
# [172.] [118.13802228]
# [63.] [91.71163023]
# [48.] [80.08401773]
# [108.] [119.19507796]
# ...

# %%
# Visualize what the predictions are for this model

plt.plot(X1_test,y1_test,'ko')

X1_new = np.linspace(-0.15,0.15,1000)
X1_new = X1_new.reshape(-1,1)
y1_pred = model.predict(X1_new)
plt.plot(X1_new, y1_pred)

plt.show()

# %%
# Visualize what the predictions are for this model

plt.plot(X1_train,y_train,'bo')

X1_new = np.linspace(-0.15,0.15,1000)
X1_new = X1_new.reshape(-1,1)

y1_pred = model.intercept_ + model.coef_ * X1_new

plt.plot(X1_new, y1_pred)

plt.show()

# %%
# Visualize what the predictions are for this model

plt.plot(X1_train,y1_train,'bo')
plt.plot(X1_test,y1_test,'ko')

X1_new = np.linspace(-0.15,0.15,1000)
X1_new = X1_new.reshape(-1,1)

y1_pred = model.intercept_ + model.coef_ * X1_new

plt.plot(X1_new, y1_pred)

plt.show()

# %%
y1_pred = model.predict(X1_test)
df_preds = pd.DataFrame({'Actual': y1_test.squeeze(), 'Predicted': y1_pred.squeeze()})
print(df_preds)
# Out:
#      Actual   Predicted
# 0     219.0  142.450303
# 1      70.0  184.732530
# 2     202.0  144.564414
# 3     230.0  199.531310
# 4     111.0  128.708579
# ..      ...         ...
# 172   199.0  123.423301
# 173   265.0  170.990806
# 174   281.0  209.044811
# 175   248.0  141.393247
# 176   257.0  227.014758
#
# [177 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score

print('MSE = ', mean_squared_error(y1_test, model.predict(X1_test)))
print('R^2 = ', r2_score(y1_test, model.predict(X1_test)))
# Out:
# MSE =  4100.02662155276
# R^2 =  0.2991646176262257

# %% [markdown]
# ### How the new values for mean squared error and R-squared scores compare (Age vs BMI)

# %% [markdown]
# #### Age:
# MSE =  5659.036676322969
# <br>
# R^2 =  0.032676248473723635
# #### BMI:
# MSE =  4100.02662155276
# <br>
# R^2 =  0.2991646176262257

# %% [markdown]
# Age has a higher MSE than BMI. This means there are more errors in the Age model than the BMI model, making the productions from the BMI model more precise. However, both MSE are relatively large meaning that they both have large amounts of errors. Similarly, the R^2 for BMI is much higher than the R^2 for Age which means that the BMI regression model better fits the observations than the Age model. Overall, the BMI model is more precise than the Age model based on the MSE and R^2.

# %% [markdown]
# ## Bonus Points

# %% [markdown]
# ### Do regression on the same data set with k-nearest neighbors

# %% [markdown]
# Perform regression with sklearn's kNN
# <br>
# Plot a scatter plot for your training data, on top of which you overlay a line plot showing the predicted values from the kNN model
# <br>
# Plot a scatter plot for your test data, on top of which you overlay a line plot showing the predicted values from the kNN model
# <br>
# Use mean_squared_error to calculate the mean squared error for your fit applied to the test data

# %%
x_knn = df2[['Age']]
y_knn = df2['Target']

df2.plot.scatter(x='Age', y='Target', title='Scatterplot of Age and Target');

# %%
import sklearn.neighbors

# Select a 3-Nearest Neighbors regression model
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)

# %%
x_knn = df2['Age'].values.reshape(-1, 1)

# %%
# Train the model
model.fit(x_knn,y_knn)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
# Train, Test, Split
x_knn_train, x_knn_test, y_knn_train, y_knn_test = train_test_split(x_knn, y_knn, test_size = 0.4, random_state = 42)

# %%
# Make a prediction
x_test = [[10]]
model.predict(x_test)
# Out:
# array([208.33333333])

# %%
# Visualize what the predictions are for this model

plt.plot(x_knn,y_knn,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
plt.plot(x_knn_train,y_knn_train,'bo')
plt.plot(x_knn_test,y_knn_test,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
print('MSE = ', mean_squared_error(y_knn, model.predict(x_knn)))
# Out:
# MSE =  6042.081196581197

# %% [markdown]
# #### Repeat for three total different values of the number of nearest neighbors used by the algorithm, and compare the mean_squared_error values you obtain.

# %% [markdown]
# #### 5-Nearest Neighbors regression model

# %%
# Select a 5-Nearest Neighbors regression model
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5)

# %%
x_knn = df2['Age'].values.reshape(-1, 1)

# %%
# Train the model
model.fit(x_knn,y_knn)
# Out:
# KNeighborsRegressor()

# %%
# Train, Test, Split
x_knn_train, x_knn_test, y_knn_train, y_knn_test = train_test_split(x_knn, y_knn, test_size = 0.4, random_state = 42)

# %%
# Make a prediction
x_test = [[10]]
model.predict(x_test)
# Out:
# array([185.])

# %%
# Visualize what the predictions are for this model

plt.plot(x_knn,y_knn,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
plt.plot(x_knn_train,y_knn_train,'bo')
plt.plot(x_knn_test,y_knn_test,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
print('MSE = ', mean_squared_error(y_knn, model.predict(x_knn)))
# Out:
# MSE =  5579.33628959276

# %% [markdown]
# #### 7-Nearest Neighbors regression model

# %%
# Select a 7-Nearest Neighbors regression model
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=7)

# %%
x_knn = df2['Age'].values.reshape(-1, 1)

# %%
# Train the model
model.fit(x_knn,y_knn)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
# Train, Test, Split
x_knn_train, x_knn_test, y_knn_train, y_knn_test = train_test_split(x_knn, y_knn, test_size = 0.4, random_state = 42)

# %%
# Make a prediction
x_test = [[10]]
model.predict(x_test)
# Out:
# array([167.85714286])

# %%
# Visualize what the predictions are for this model

plt.plot(x_knn,y_knn,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
plt.plot(x_knn_train,y_knn_train,'bo')
plt.plot(x_knn_test,y_knn_test,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
print('MSE = ', mean_squared_error(y_knn, model.predict(x_knn)))
# Out:
# MSE =  5400.7691384246

# %% [markdown]
# #### 10-Nearest Neighbors regression model

# %%
# Select a 10-Nearest Neighbors regression model
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=10)

# %%
x_knn = df2['Age'].values.reshape(-1, 1)

# %%
# Train the model
model.fit(x_knn,y_knn)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
# Train, Test, Split
x_knn_train, x_knn_test, y_knn_train, y_knn_test = train_test_split(x_knn, y_knn, test_size = 0.4, random_state = 42)

# %%
# Make a prediction
x_test = [[10]]
model.predict(x_test)
# Out:
# array([166.])

# %%
# Visualize what the predictions are for this model

plt.plot(x_knn,y_knn,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
plt.plot(x_knn_train,y_knn_train,'bo')
plt.plot(x_knn_test,y_knn_test,'ko')

x_new = np.linspace(-0.13,0.13,1000)
x_new = x_new.reshape(-1,1)
y_pred = model.predict(x_new)
plt.plot(x_new, y_pred)

plt.show()

# %%
print('MSE = ', mean_squared_error(y_knn, model.predict(x_knn)))
# Out:
# MSE =  5342.169615384615

# %% [markdown]
# ### MSE Comparison

# %% [markdown]
# #### 3-Nearest Neighbors regression model
# MSE =  6042.081196581197
#
# #### 5-Nearest Neighbors regression model
# MSE =  5579.33628959276
#
# #### 7-Nearest Neighbors regression model
# MSE =  5400.7691384246
#
# #### 10-Nearest Neighbors regression model
# MSE =  5342.169615384615
#
# #### Conclusion
# MSE decreases and becomes more precise as the number of nearest neighbors goes up.
